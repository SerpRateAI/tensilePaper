# %%
# !pip install ipympl

# %%
from pvel_util import *

# %%
catalog = import_catalog(file='188precision.csv')

# %%
catalog[catalog.id.between(100, 200)]
# Out:
#       id    depth  relative_depth  first_hydrophone  second_hydrophone  \
# 100  100  169.125          -0.875                 2                  3
# 101  101  170.000           0.000                 2                  3
# 110  110  176.125           6.125                 2                  3
# 113  113  110.500         -59.500                 2                  5
# 119  119  170.000           0.000                 2                  3
# 125  125  170.000           0.000                 2                  3
# 126  126  170.000           0.000                 2                  3
# 130  130  178.750           8.750                 2                  3
# 131  131  171.750           1.750                 2                  3
# 132  132  170.000           0.000                 2                  3
# 134  134  180.500          10.500                 2                  3
# 135  135  181.375          11.375                 2                  3
# ...

# %%
# vels = []
# depths = []
# ptimes = []

# %%
# %matplotlib widget
plot_event_for_p_pick(event_id=177, ptime=0.196, day_number=188, catalog=catalog)
# Out:
# origin time: 2019-07-07T09:03:38.521999Z
# p velocity: -3500.0
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_event_for_p_pick(event_id=245, ptime=0.194, day_number=188, catalog=catalog)
# Out:
# origin time: 2019-07-07T09:04:33.228999Z
# p velocity: 2624.999999999998
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_event_for_p_pick(event_id=354, ptime=0.196, day_number=188, catalog=catalog)
# Out:
# origin time: 2019-07-07T09:05:56.416499Z
# p velocity: -3250.0
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
catalog[catalog.id.between(490, 590)]
# Out:
#       id       depth  relative_depth  first_hydrophone  second_hydrophone  \
# 492  492  183.125000       13.125000                 2                  3
# 499  499  191.875000       21.875000                 2                  3
# 500  500  184.000000       14.000000                 2                  3
# 503  503  197.125000       27.125000                 2                  5
# 504  504  184.000000       14.000000                 2                  4
# 506  506  166.500000       -3.500000                 2                  4
# 509  509  192.750000       22.750000                 2                  3
# 510  510  192.750875       22.750875                 2                  3
# 511  511  205.875000       35.875000                 3                  2
# 512  512  206.750000       36.750000                 3                  2
# 515  515  206.750000       36.750000                 3                  2
# 520  520  158.625000      -11.375000                 2                  3
# ...

# %%
plot_event_for_p_pick(event_id=528, ptime=0.193, day_number=188, catalog=catalog)
# Out:
# origin time: 2019-07-07T09:08:38.408999Z
# p velocity: -8750.0
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_event_for_p_pick(event_id=650, ptime=0.196, day_number=188, catalog=catalog)
# Out:
# origin time: 2019-07-07T09:12:39.565999Z
# p velocity: -2312.5
# /home/mnky9800n/repos/boreholeCrack/event_pipeline.py:202: RuntimeWarning: invalid value encountered in sqrt
#   self.radius =  np.sqrt(vrock**2 * dt**2 - dz**2)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_event_for_p_pick(event_id=775, ptime=0.195, day_number=188, catalog=catalog)
# Out:
# origin time: 2019-07-07T09:16:36.820499Z
# p velocity: -2131.818181818182
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_event_for_p_pick(event_id=813, ptime=0.195, day_number=188, catalog=catalog)
# Out:
# origin time: 2019-07-07T09:17:04.797999Z
# p velocity: -2051.7241379310344
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_event_for_p_pick(event_id=1002, ptime=0.197, day_number=188, catalog=catalog)
# Out:
# origin time: 2019-07-07T09:19:34.148499Z
# p velocity: -2161.7647058823527
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_event_for_p_pick(event_id=1173, ptime=0.196, day_number=188, catalog=catalog)
# Out:
# origin time: 2019-07-07T09:21:37.791499Z
# p velocity: -4550.0
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_event_for_p_pick(event_id=1211, ptime=0.196, day_number=188, catalog=catalog)
# Out:
# origin time: 2019-07-07T09:21:55.889999Z
# p velocity: -51.470588235294116
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_event_for_p_pick(event_id=1594, ptime=0.194, day_number=188, catalog=catalog)
# Out:
# origin time: 2019-07-07T09:26:03.697499Z
# p velocity: -4083.3333333333335
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_event_for_p_pick(event_id=1675, ptime=0.195, day_number=188, catalog=catalog)
# Out:
# origin time: 2019-07-07T09:27:35.887499Z
# p velocity: -4104.545454545455
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_event_for_p_pick(event_id=1742, ptime=0.195, day_number=188, catalog=catalog)
# Out:
# origin time: 2019-07-07T09:28:40.938499Z
# p velocity: -7349.999999999999
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_event_for_p_pick(event_id=1807, ptime=0.1942096, day_number=188, catalog=catalog)
# Out:
# origin time: 2019-07-07T09:29:38.266499Z
# p velocity: -2696.078431372549
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_event_for_p_pick(event_id=2096, ptime=0.194, day_number=188, catalog=catalog)
# Out:
# origin time: 2019-07-07T09:36:28.463999Z
# p velocity: -2100.0
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_event_for_p_pick(event_id=2196, ptime=0.191, day_number=188, catalog=catalog)
# Out:
# origin time: 2019-07-07T09:38:02.599999Z
# p velocity: -2258.064516129032
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_event_for_p_pick(event_id=2276, ptime=0.196, day_number=188, catalog=catalog)
# Out:
# origin time: 2019-07-07T09:40:50.044999Z
# p velocity: -2625.0
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_event_for_p_pick(event_id=2390, ptime=0.190, day_number=188, catalog=catalog)
# Out:
# origin time: 2019-07-07T09:34:45.987499Z
# p velocity: -2563.953488372093
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_event_for_p_pick(event_id=2414, ptime=0.193, day_number=188, catalog=catalog)
# Out:
# origin time: 2019-07-07T09:35:57.222499Z
# p velocity: -2046.1538461538462
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_event_for_p_pick(event_id=2502, ptime=0.193, day_number=188, catalog=catalog)
# Out:
# origin time: 2019-07-07T09:40:08.184499Z
# p velocity: -2230.4796266520257
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_event_for_p_pick(event_id=2698, ptime=0.190, day_number=188, catalog=catalog)
# Out:
# /home/mnky9800n/repos/boreholeCrack/pvel_util.py:157: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize=(15, 5))
# origin time: 2019-07-07T09:50:08.196499Z
# p velocity: -2569.148936170213
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_event_for_p_pick(event_id=2706, ptime=0.189, day_number=188, catalog=catalog)
# Out:
# origin time: 2019-07-07T09:50:31.819499Z
# p velocity: -2569.148936170213
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
catalog[catalog.id.between(2700, 2800)]
# Out:
#         id    depth  relative_depth  first_hydrophone  second_hydrophone  \
# 2700  2700  368.625          58.625                 5                  4
# 2703  2703  370.375          60.375                 5                  4
# 2704  2704  370.375          60.375                 5                  4
# 2705  2705  370.375          60.375                 5                  4
# 2706  2706  370.375          60.375                 5                  4
# ...    ...      ...             ...               ...                ...
# 2794  2794  352.875          42.875                 5                  4
# 2795  2795  352.875          42.875                 5                  4
# 2796  2796  368.625          58.625                 5                  4
# 2797  2797  367.750          57.750                 5                  4
# 2800  2800  361.625          51.625                 5                  4
#
#       arrival_time                     first_arrival  \
# ...

# %%
np.abs(vels).mean()
# Out:
# 3117.2810992166196

# %%
np.abs(ptimes).mean()
# Out:
# 0.005990472727272733

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 5))

colors = np.linspace(0, 1, len(depths))

ax[0].scatter(depths, ptimes, c=plt.cm.Spectral(colors))
ax[0].set_xlabel('depth (meters)')
ax[0].set_ylabel('origin time - p_arrival time')

ax[1].scatter(depths, np.abs(vels), c=plt.cm.Spectral(colors))
ax[1].hlines(y=np.abs(vels).mean(), xmin=175, xmax=400, color='red')
# ax[1].set_xlim(175, 400)
ax[1].set_xlabel('depth (meters)')
ax[1].set_ylabel('velocity m/s')

ax[2].scatter(ptimes, vels, c=plt.cm.Spectral(colors))
ax[2].set_xlabel('origin time - p_arrival time')
ax[2].set_ylabel('velocity m/s')

fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.cm.Spectral

# %%
pd.DataFrame({'depths':depths, 'ptimes':ptimes, 'velocity':vels}).to_csv('pvels188.csv', index=False)
